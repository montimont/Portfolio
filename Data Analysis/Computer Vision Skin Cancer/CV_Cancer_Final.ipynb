# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import requests
import zipfile
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
from tqdm.auto import tqdm
from typing import Tuple, Dict, List
import pandas as pd

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device

data_path = Path("/content/drive/MyDrive/")
image_path = data_path / "Skin_Data_2"

# %%
train_dir = image_path / "train"
test_dir = image_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('/content/drive/MyDrive/Skin_Data_2/train'),
#  PosixPath('/content/drive/MyDrive/Skin_Data_2/test'))

# %%
image_path_list = list(image_path.glob("*/*/*.jpg"))
random_image_path = random.choice(image_path_list)
image_class = random_image_path.parent.stem
img = Image.open(random_image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9cb955ad1582> in <cell line: 1>()
# ----> 1 image_path_list = list(image_path.glob("*/*/*.jpg"))
#       2 random_image_path = random.choice(image_path_list)
#       3 image_class = random_image_path.parent.stem
#       4 img = Image.open(random_image_path)
#
# NameError: name 'image_path' is not defined

# %%
img_as_array = np.asarray(img)
plt.figure(figsize=(10, 7))
plt.imshow(img_as_array)
plt.title(f"Image class: {image_class} | Image shape: {img_as_array.shape} -> [height, width, color_channels]")
plt.axis(False);

# %%
data_transform = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# %%
def plot_transformed_images(image_paths, transform, n=3, seed=42):
    random.seed(seed)
    random_image_paths = random.sample(image_paths, k=n)
    for image_path in random_image_paths:
        with Image.open(image_path) as f:
            fig, ax = plt.subplots(1, 2)
            ax[0].imshow(f)
            ax[0].set_title(f"Original \nSize: {f.size}")
            ax[0].axis("off")
            transformed_image = transform(f).permute(1, 2, 0)
            ax[1].imshow(transformed_image)
            ax[1].set_title(f"Transformed \nSize: {transformed_image.shape}")
            ax[1].axis("off")

            fig.suptitle(f"Class: {image_path.parent.stem}", fontsize=16)

plot_transformed_images(image_path_list,
                        transform=data_transform,
                        n=3)

# %%
train_data = datasets.ImageFolder(root=train_dir, # target folder of images
                                  transform=data_transform, # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)

test_data = datasets.ImageFolder(root=test_dir,
                                 transform=data_transform)

class_names = train_data.classes
class_dict = train_data.class_to_idx

len(train_data), len(test_data)
# Out:
# (204, 84)

# %%
img, label = train_data[0][0], train_data[0][1]
img_permute = img.permute(1, 2, 0)

print(f"Original shape: {img.shape} -> [color_channels, height, width]")
print(f"Image permute shape: {img_permute.shape} -> [height, width, color_channels]")

plt.figure(figsize=(10, 7))
plt.imshow(img.permute(1, 2, 0))
plt.axis("off")
plt.title(class_names[label], fontsize=14);
# Out:
# Original shape: torch.Size([3, 64, 64]) -> [color_channels, height, width]
# Image permute shape: torch.Size([64, 64, 3]) -> [height, width, color_channels]

# %%
train_dataloader = DataLoader(dataset=train_data,
                              batch_size=1,
                              num_workers=1,
                              shuffle=True)

test_dataloader = DataLoader(dataset=test_data,
                             batch_size=1,
                             num_workers=1,
                             shuffle=False)

# %%
img, label = next(iter(train_dataloader))
print(f"Image shape: {img.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label.shape}")
# Out:
# Image shape: torch.Size([1, 3, 64, 64]) -> [batch_size, color_channels, height, width]
# Label shape: torch.Size([1])

# %%
simple_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])

# %%
train_data_simple = datasets.ImageFolder(root=train_dir, transform=simple_transform)
test_data_simple = datasets.ImageFolder(root=test_dir, transform=simple_transform)
BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()
print(f"Creating DataLoader's with batch size {BATCH_SIZE} and {NUM_WORKERS} workers.")

train_dataloader_simple = DataLoader(train_data_simple,
                                     batch_size=BATCH_SIZE,
                                     shuffle=True,
                                     num_workers=NUM_WORKERS)

test_dataloader_simple = DataLoader(test_data_simple,
                                    batch_size=BATCH_SIZE,
                                    shuffle=False,
                                    num_workers=NUM_WORKERS)
# Out:
# Creating DataLoader's with batch size 32 and 2 workers.

# %%
class TinyVGG(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int) -> None:
        super().__init__()
        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2)
        )
        self.conv_block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=hidden_units*16*16,
                      out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        x = self.conv_block_1(x)
        x = self.conv_block_2(x)
        x = self.classifier(x)
        return x

torch.manual_seed(42)
model_0 = TinyVGG(input_shape=3,
                  hidden_units=10,
                  output_shape=len(train_data.classes)).to(device)

# %%
img_batch, label_batch = next(iter(train_dataloader_simple))

img_single, label_single = img_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single image shape: {img_single.shape}\n")

model_0.eval()
with torch.inference_mode():
    pred = model_0(img_single.to(device))
# Out:
# Single image shape: torch.Size([1, 3, 64, 64])

# %%
# !pip install torchinfo

from torchinfo import summary
summary(model_0, input_size=[1, 3, 64, 64])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.9/dist-packages (1.7.2)
# /usr/local/lib/python3.9/dist-packages/torchinfo/torchinfo.py:477: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   action_fn=lambda data: sys.getsizeof(data.storage()),
# /usr/local/lib/python3.9/dist-packages/torch/storage.py:665: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return super().__sizeof__() + self.nbytes()
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [1, 2]                    --
# ├─Sequential: 1-1                        [1, 10, 32, 32]           --
# │    └─Conv2d: 2-1                       [1, 10, 64, 64]           280
# │    └─ReLU: 2-2                         [1, 10, 64, 64]           --
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           910
# │    └─ReLU: 2-4                         [1, 10, 64, 64]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 32, 32]           --
# ├─Sequential: 1-2                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-6                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-7                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-8                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-9                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 16, 16]           --
# ├─Sequential: 1-3                        [1, 2]                    --
# │    └─Flatten: 2-11                     [1, 2560]                 --
# │    └─Linear: 2-12                      [1, 2]                    5,122
# ==========================================================================================
# Total params: 8,132
# Trainable params: 8,132
# Non-trainable params: 0
# Total mult-adds (M): 6.74
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.90
# ==========================================================================================

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    model.train()

    train_loss, train_acc = 0, 0

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_pred = model(X)

        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    model.eval()

    test_loss, test_acc = 0, 0

    with torch.inference_mode():
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            test_pred_logits = model(X)

            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    return results

# %%
NUM_EPOCHS = 250

model_0 = TinyVGG(input_shape=3,
                  hidden_units=6,
                  output_shape=len(train_data.classes)).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.001)

from timeit import default_timer as timer
start_time = timer()

model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader_simple,
                        test_dataloader=test_dataloader_simple,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.6315 | train_acc: 0.7009 | test_loss: 0.7117 | test_acc: 0.5625
# Epoch: 2 | train_loss: 0.5133 | train_acc: 0.7976 | test_loss: 0.9289 | test_acc: 0.5625
# Epoch: 3 | train_loss: 0.5237 | train_acc: 0.7976 | test_loss: 0.9416 | test_acc: 0.5625
# Epoch: 4 | train_loss: 0.4878 | train_acc: 0.8125 | test_loss: 0.8185 | test_acc: 0.5625
# Epoch: 5 | train_loss: 0.5119 | train_acc: 0.7902 | test_loss: 0.8241 | test_acc: 0.5625
# Epoch: 6 | train_loss: 0.5098 | train_acc: 0.7902 | test_loss: 0.8180 | test_acc: 0.5625
# Epoch: 7 | train_loss: 0.5091 | train_acc: 0.7902 | test_loss: 0.8334 | test_acc: 0.5625
# Epoch: 8 | train_loss: 0.4990 | train_acc: 0.7976 | test_loss: 0.8271 | test_acc: 0.5625
# Epoch: 9 | train_loss: 0.5274 | train_acc: 0.7827 | test_loss: 0.8761 | test_acc: 0.5625
# Epoch: 10 | train_loss: 0.4976 | train_acc: 0.7976 | test_loss: 0.7979 | test_acc: 0.5625
# Epoch: 11 | train_loss: 0.4863 | train_acc: 0.8051 | test_loss: 0.8194 | test_acc: 0.5625
# Epoch: 12 | train_loss: 0.4730 | train_acc: 0.8051 | test_loss: 0.9092 | test_acc: 0.5625
# Epoch: 13 | train_loss: 0.4636 | train_acc: 0.8125 | test_loss: 0.8647 | test_acc: 0.5625
# Epoch: 14 | train_loss: 0.4753 | train_acc: 0.7976 | test_loss: 0.8214 | test_acc: 0.5625
# Epoch: 15 | train_loss: 0.4342 | train_acc: 0.8051 | test_loss: 0.7785 | test_acc: 0.5625
# Epoch: 16 | train_loss: 0.4612 | train_acc: 0.7842 | test_loss: 0.7443 | test_acc: 0.5938
# Epoch: 17 | train_loss: 0.4078 | train_acc: 0.7902 | test_loss: 0.7953 | test_acc: 0.5729
# Epoch: 18 | train_loss: 0.3952 | train_acc: 0.8199 | test_loss: 0.6907 | test_acc: 0.6083
# Epoch: 19 | train_loss: 0.3738 | train_acc: 0.8140 | test_loss: 0.7900 | test_acc: 0.6083
# Epoch: 20 | train_loss: 0.3821 | train_acc: 0.8080 | test_loss: 0.7427 | test_acc: 0.6292
# Epoch: 21 | train_loss: 0.3375 | train_acc: 0.8527 | test_loss: 0.6262 | test_acc: 0.6646
# Epoch: 22 | train_loss: 0.3427 | train_acc: 0.8616 | test_loss: 0.7414 | test_acc: 0.6396
# Epoch: 23 | train_loss: 0.3543 | train_acc: 0.8318 | test_loss: 0.5524 | test_acc: 0.7417
# Epoch: 24 | train_loss: 0.3447 | train_acc: 0.8497 | test_loss: 1.0921 | test_acc: 0.5833
# Epoch: 25 | train_loss: 0.4018 | train_acc: 0.8274 | test_loss: 0.5900 | test_acc: 0.6854
# Epoch: 26 | train_loss: 0.3504 | train_acc: 0.8304 | test_loss: 0.8236 | test_acc: 0.6083
# Epoch: 27 | train_loss: 0.3365 | train_acc: 0.8289 | test_loss: 0.5925 | test_acc: 0.6854
# Epoch: 28 | train_loss: 0.3976 | train_acc: 0.8080 | test_loss: 0.6439 | test_acc: 0.6542
# Epoch: 29 | train_loss: 0.3990 | train_acc: 0.8690 | test_loss: 0.5509 | test_acc: 0.7375
# Epoch: 30 | train_loss: 0.3874 | train_acc: 0.8244 | test_loss: 0.8309 | test_acc: 0.5875
# Epoch: 31 | train_loss: 0.3310 | train_acc: 0.8497 | test_loss: 0.5671 | test_acc: 0.6896
# Epoch: 32 | train_loss: 0.3155 | train_acc: 0.8661 | test_loss: 0.7267 | test_acc: 0.6500
# Epoch: 33 | train_loss: 0.3452 | train_acc: 0.8095 | test_loss: 0.6666 | test_acc: 0.6646
# Epoch: 34 | train_loss: 0.3439 | train_acc: 0.8542 | test_loss: 0.5636 | test_acc: 0.7271
# Epoch: 35 | train_loss: 0.2964 | train_acc: 0.8601 | test_loss: 0.8950 | test_acc: 0.6083
# Epoch: 36 | train_loss: 0.3283 | train_acc: 0.8289 | test_loss: 0.6038 | test_acc: 0.6854
# Epoch: 37 | train_loss: 0.2970 | train_acc: 0.9018 | test_loss: 0.6004 | test_acc: 0.7062
# Epoch: 38 | train_loss: 0.2867 | train_acc: 0.8735 | test_loss: 0.7495 | test_acc: 0.6604
# Epoch: 39 | train_loss: 0.2837 | train_acc: 0.8631 | test_loss: 0.6042 | test_acc: 0.7375
# Epoch: 40 | train_loss: 0.2869 | train_acc: 0.9018 | test_loss: 0.6643 | test_acc: 0.7125
# Epoch: 41 | train_loss: 0.2879 | train_acc: 0.8646 | test_loss: 0.6538 | test_acc: 0.7021
# Epoch: 42 | train_loss: 0.2717 | train_acc: 0.8914 | test_loss: 0.6346 | test_acc: 0.7479
# Epoch: 43 | train_loss: 0.2683 | train_acc: 0.8854 | test_loss: 0.6704 | test_acc: 0.7229
# Epoch: 44 | train_loss: 0.2734 | train_acc: 0.8958 | test_loss: 0.6230 | test_acc: 0.7313
# Epoch: 45 | train_loss: 0.2623 | train_acc: 0.9107 | test_loss: 0.6888 | test_acc: 0.7333
# Epoch: 46 | train_loss: 0.2484 | train_acc: 0.9033 | test_loss: 0.6697 | test_acc: 0.7438
# Epoch: 47 | train_loss: 0.2587 | train_acc: 0.9077 | test_loss: 0.6644 | test_acc: 0.7583
# Epoch: 48 | train_loss: 0.2958 | train_acc: 0.8839 | test_loss: 0.6739 | test_acc: 0.7687
# Epoch: 49 | train_loss: 0.2590 | train_acc: 0.9003 | test_loss: 0.6353 | test_acc: 0.7417
# Epoch: 50 | train_loss: 0.2450 | train_acc: 0.9033 | test_loss: 0.7237 | test_acc: 0.7167
# Epoch: 51 | train_loss: 0.2397 | train_acc: 0.9107 | test_loss: 0.6920 | test_acc: 0.7417
# Epoch: 52 | train_loss: 0.2194 | train_acc: 0.9107 | test_loss: 0.8044 | test_acc: 0.7125
# Epoch: 53 | train_loss: 0.2239 | train_acc: 0.9062 | test_loss: 0.7099 | test_acc: 0.7417
# Epoch: 54 | train_loss: 0.2096 | train_acc: 0.9107 | test_loss: 0.8119 | test_acc: 0.7333
# Epoch: 55 | train_loss: 0.2067 | train_acc: 0.9241 | test_loss: 0.8661 | test_acc: 0.7229
# Epoch: 56 | train_loss: 0.2191 | train_acc: 0.9167 | test_loss: 0.7302 | test_acc: 0.7708
# Epoch: 57 | train_loss: 0.2037 | train_acc: 0.9286 | test_loss: 0.9597 | test_acc: 0.6813
# Epoch: 58 | train_loss: 0.1975 | train_acc: 0.9241 | test_loss: 0.7295 | test_acc: 0.7771
# Epoch: 59 | train_loss: 0.1763 | train_acc: 0.9375 | test_loss: 0.9569 | test_acc: 0.7125
# Epoch: 60 | train_loss: 0.1678 | train_acc: 0.9420 | test_loss: 0.8419 | test_acc: 0.7542
# Epoch: 61 | train_loss: 0.1866 | train_acc: 0.9375 | test_loss: 0.8602 | test_acc: 0.7354
# Epoch: 62 | train_loss: 0.1614 | train_acc: 0.9464 | test_loss: 0.9852 | test_acc: 0.7333
# Epoch: 63 | train_loss: 0.1939 | train_acc: 0.9271 | test_loss: 0.9930 | test_acc: 0.7375
# Epoch: 64 | train_loss: 0.2328 | train_acc: 0.9167 | test_loss: 1.0772 | test_acc: 0.6813
# Epoch: 65 | train_loss: 0.2077 | train_acc: 0.9092 | test_loss: 0.9020 | test_acc: 0.7542
# Epoch: 66 | train_loss: 0.1447 | train_acc: 0.9464 | test_loss: 1.5490 | test_acc: 0.6813
# Epoch: 67 | train_loss: 0.1919 | train_acc: 0.9375 | test_loss: 0.8449 | test_acc: 0.7604
# Epoch: 68 | train_loss: 0.1251 | train_acc: 0.9643 | test_loss: 1.1910 | test_acc: 0.7438
# Epoch: 69 | train_loss: 0.1373 | train_acc: 0.9479 | test_loss: 1.0436 | test_acc: 0.7333
# Epoch: 70 | train_loss: 0.1475 | train_acc: 0.9464 | test_loss: 1.0941 | test_acc: 0.7271
# Epoch: 71 | train_loss: 0.1078 | train_acc: 0.9777 | test_loss: 1.0173 | test_acc: 0.7667
# Epoch: 72 | train_loss: 0.1105 | train_acc: 0.9732 | test_loss: 1.2207 | test_acc: 0.7271
# Epoch: 73 | train_loss: 0.1023 | train_acc: 0.9732 | test_loss: 1.2678 | test_acc: 0.7271
# Epoch: 74 | train_loss: 0.0990 | train_acc: 0.9643 | test_loss: 1.6502 | test_acc: 0.7396
# Epoch: 75 | train_loss: 0.1067 | train_acc: 0.9598 | test_loss: 1.0965 | test_acc: 0.7333
# Epoch: 76 | train_loss: 0.1105 | train_acc: 0.9658 | test_loss: 1.4442 | test_acc: 0.7167
# Epoch: 77 | train_loss: 0.0860 | train_acc: 0.9732 | test_loss: 1.3665 | test_acc: 0.7250
# Epoch: 78 | train_loss: 0.0803 | train_acc: 0.9688 | test_loss: 1.3114 | test_acc: 0.7333
# Epoch: 79 | train_loss: 0.0916 | train_acc: 0.9777 | test_loss: 1.5347 | test_acc: 0.7271
# Epoch: 80 | train_loss: 0.0627 | train_acc: 0.9821 | test_loss: 1.4239 | test_acc: 0.7396
# Epoch: 81 | train_loss: 0.0635 | train_acc: 0.9866 | test_loss: 1.7900 | test_acc: 0.7375
# Epoch: 82 | train_loss: 0.0577 | train_acc: 0.9821 | test_loss: 1.4768 | test_acc: 0.7292
# Epoch: 83 | train_loss: 0.0657 | train_acc: 0.9821 | test_loss: 1.6351 | test_acc: 0.7479
# Epoch: 84 | train_loss: 0.0512 | train_acc: 0.9911 | test_loss: 1.5602 | test_acc: 0.7292
# Epoch: 85 | train_loss: 0.0553 | train_acc: 0.9821 | test_loss: 1.8581 | test_acc: 0.7375
# Epoch: 86 | train_loss: 0.0533 | train_acc: 0.9881 | test_loss: 1.6327 | test_acc: 0.7188
# Epoch: 87 | train_loss: 0.0585 | train_acc: 0.9866 | test_loss: 2.0299 | test_acc: 0.7229
# Epoch: 88 | train_loss: 0.0508 | train_acc: 0.9836 | test_loss: 1.9749 | test_acc: 0.7375
# Epoch: 89 | train_loss: 0.0742 | train_acc: 0.9821 | test_loss: 1.4860 | test_acc: 0.7333
# Epoch: 90 | train_loss: 0.0715 | train_acc: 0.9702 | test_loss: 1.9386 | test_acc: 0.6958
# Epoch: 91 | train_loss: 0.0487 | train_acc: 0.9911 | test_loss: 1.7424 | test_acc: 0.7292
# Epoch: 92 | train_loss: 0.0381 | train_acc: 0.9866 | test_loss: 2.3034 | test_acc: 0.7438
# Epoch: 93 | train_loss: 0.0326 | train_acc: 0.9955 | test_loss: 2.1200 | test_acc: 0.7313
# Epoch: 94 | train_loss: 0.0321 | train_acc: 0.9955 | test_loss: 2.0445 | test_acc: 0.7292
# Epoch: 95 | train_loss: 0.0210 | train_acc: 1.0000 | test_loss: 2.4775 | test_acc: 0.7062
# Epoch: 96 | train_loss: 0.0221 | train_acc: 0.9955 | test_loss: 2.2015 | test_acc: 0.7354
# Epoch: 97 | train_loss: 0.0152 | train_acc: 1.0000 | test_loss: 2.6702 | test_acc: 0.7271
# Epoch: 98 | train_loss: 0.0158 | train_acc: 1.0000 | test_loss: 2.3348 | test_acc: 0.7292
# Epoch: 99 | train_loss: 0.0143 | train_acc: 1.0000 | test_loss: 2.6513 | test_acc: 0.7208
# Epoch: 100 | train_loss: 0.0116 | train_acc: 1.0000 | test_loss: 2.4611 | test_acc: 0.7313
# Epoch: 101 | train_loss: 0.0091 | train_acc: 1.0000 | test_loss: 2.7419 | test_acc: 0.7208
# Epoch: 102 | train_loss: 0.0101 | train_acc: 1.0000 | test_loss: 2.7032 | test_acc: 0.7313
# Epoch: 103 | train_loss: 0.0084 | train_acc: 1.0000 | test_loss: 2.6495 | test_acc: 0.7417
# Epoch: 104 | train_loss: 0.0071 | train_acc: 1.0000 | test_loss: 2.9042 | test_acc: 0.7208
# Epoch: 105 | train_loss: 0.0072 | train_acc: 1.0000 | test_loss: 2.7197 | test_acc: 0.7458
# Epoch: 106 | train_loss: 0.0063 | train_acc: 1.0000 | test_loss: 2.9962 | test_acc: 0.7208
# Epoch: 107 | train_loss: 0.0066 | train_acc: 1.0000 | test_loss: 2.9821 | test_acc: 0.7313
# Epoch: 108 | train_loss: 0.0052 | train_acc: 1.0000 | test_loss: 3.1459 | test_acc: 0.7208
# Epoch: 109 | train_loss: 0.0058 | train_acc: 1.0000 | test_loss: 3.0207 | test_acc: 0.7417
# Epoch: 110 | train_loss: 0.0052 | train_acc: 1.0000 | test_loss: 3.1262 | test_acc: 0.7417
# Epoch: 111 | train_loss: 0.0046 | train_acc: 1.0000 | test_loss: 3.1714 | test_acc: 0.7313
# Epoch: 112 | train_loss: 0.0039 | train_acc: 1.0000 | test_loss: 3.1362 | test_acc: 0.7417
# Epoch: 113 | train_loss: 0.0036 | train_acc: 1.0000 | test_loss: 3.3012 | test_acc: 0.7313
# Epoch: 114 | train_loss: 0.0036 | train_acc: 1.0000 | test_loss: 3.1946 | test_acc: 0.7417
# Epoch: 115 | train_loss: 0.0034 | train_acc: 1.0000 | test_loss: 3.2635 | test_acc: 0.7313
# Epoch: 116 | train_loss: 0.0029 | train_acc: 1.0000 | test_loss: 3.3745 | test_acc: 0.7479
# Epoch: 117 | train_loss: 0.0028 | train_acc: 1.0000 | test_loss: 3.4270 | test_acc: 0.7479
# Epoch: 118 | train_loss: 0.0027 | train_acc: 1.0000 | test_loss: 3.3693 | test_acc: 0.7479
# Epoch: 119 | train_loss: 0.0025 | train_acc: 1.0000 | test_loss: 3.5920 | test_acc: 0.7271
# Epoch: 120 | train_loss: 0.0033 | train_acc: 1.0000 | test_loss: 3.5571 | test_acc: 0.7375
# Epoch: 121 | train_loss: 0.0023 | train_acc: 1.0000 | test_loss: 3.5401 | test_acc: 0.7479
# Epoch: 122 | train_loss: 0.0021 | train_acc: 1.0000 | test_loss: 3.5642 | test_acc: 0.7375
# Epoch: 123 | train_loss: 0.0023 | train_acc: 1.0000 | test_loss: 3.5340 | test_acc: 0.7479
# Epoch: 124 | train_loss: 0.0026 | train_acc: 1.0000 | test_loss: 3.7011 | test_acc: 0.7271
# Epoch: 125 | train_loss: 0.0020 | train_acc: 1.0000 | test_loss: 3.5254 | test_acc: 0.7583
# Epoch: 126 | train_loss: 0.0018 | train_acc: 1.0000 | test_loss: 3.6334 | test_acc: 0.7479
# Epoch: 127 | train_loss: 0.0016 | train_acc: 1.0000 | test_loss: 3.6156 | test_acc: 0.7479
# Epoch: 128 | train_loss: 0.0015 | train_acc: 1.0000 | test_loss: 3.7008 | test_acc: 0.7479
# Epoch: 129 | train_loss: 0.0015 | train_acc: 1.0000 | test_loss: 3.6896 | test_acc: 0.7479
# Epoch: 130 | train_loss: 0.0015 | train_acc: 1.0000 | test_loss: 3.7155 | test_acc: 0.7479
# Epoch: 131 | train_loss: 0.0016 | train_acc: 1.0000 | test_loss: 3.7625 | test_acc: 0.7479
# Epoch: 132 | train_loss: 0.0014 | train_acc: 1.0000 | test_loss: 3.7585 | test_acc: 0.7479
# Epoch: 133 | train_loss: 0.0013 | train_acc: 1.0000 | test_loss: 3.7399 | test_acc: 0.7687
# Epoch: 134 | train_loss: 0.0016 | train_acc: 1.0000 | test_loss: 3.8433 | test_acc: 0.7375
# Epoch: 135 | train_loss: 0.0012 | train_acc: 1.0000 | test_loss: 3.8107 | test_acc: 0.7479
# Epoch: 136 | train_loss: 0.0013 | train_acc: 1.0000 | test_loss: 3.8493 | test_acc: 0.7479
# Epoch: 137 | train_loss: 0.0013 | train_acc: 1.0000 | test_loss: 3.8604 | test_acc: 0.7479
# Epoch: 138 | train_loss: 0.0011 | train_acc: 1.0000 | test_loss: 3.9035 | test_acc: 0.7479
# Epoch: 139 | train_loss: 0.0011 | train_acc: 1.0000 | test_loss: 3.9671 | test_acc: 0.7375
# Epoch: 140 | train_loss: 0.0012 | train_acc: 1.0000 | test_loss: 3.9041 | test_acc: 0.7479
# Epoch: 141 | train_loss: 0.0010 | train_acc: 1.0000 | test_loss: 3.9992 | test_acc: 0.7375
# Epoch: 142 | train_loss: 0.0012 | train_acc: 1.0000 | test_loss: 3.9744 | test_acc: 0.7479
# Epoch: 143 | train_loss: 0.0011 | train_acc: 1.0000 | test_loss: 3.9465 | test_acc: 0.7479
# Epoch: 144 | train_loss: 0.0009 | train_acc: 1.0000 | test_loss: 4.0627 | test_acc: 0.7375
# Epoch: 145 | train_loss: 0.0009 | train_acc: 1.0000 | test_loss: 4.0020 | test_acc: 0.7479
# Epoch: 146 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.0845 | test_acc: 0.7375
# Epoch: 147 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.0680 | test_acc: 0.7375
# Epoch: 148 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.1255 | test_acc: 0.7375
# Epoch: 149 | train_loss: 0.0009 | train_acc: 1.0000 | test_loss: 4.0944 | test_acc: 0.7479
# Epoch: 150 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.0850 | test_acc: 0.7479
# Epoch: 151 | train_loss: 0.0009 | train_acc: 1.0000 | test_loss: 4.1986 | test_acc: 0.7375
# Epoch: 152 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.0661 | test_acc: 0.7583
# Epoch: 153 | train_loss: 0.0009 | train_acc: 1.0000 | test_loss: 4.2078 | test_acc: 0.7375
# Epoch: 154 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.1135 | test_acc: 0.7583
# Epoch: 155 | train_loss: 0.0007 | train_acc: 1.0000 | test_loss: 4.2735 | test_acc: 0.7271
# Epoch: 156 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.1504 | test_acc: 0.7583
# Epoch: 157 | train_loss: 0.0007 | train_acc: 1.0000 | test_loss: 4.1549 | test_acc: 0.7583
# Epoch: 158 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.3101 | test_acc: 0.7271
# Epoch: 159 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.1985 | test_acc: 0.7583
# Epoch: 160 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.2401 | test_acc: 0.7479
# Epoch: 161 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.2940 | test_acc: 0.7375
# Epoch: 162 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.2786 | test_acc: 0.7375
# Epoch: 163 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.2720 | test_acc: 0.7479
# Epoch: 164 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.3535 | test_acc: 0.7375
# Epoch: 165 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.2893 | test_acc: 0.7479
# Epoch: 166 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.3176 | test_acc: 0.7479
# Epoch: 167 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.4545 | test_acc: 0.7271
# Epoch: 168 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.3242 | test_acc: 0.7479
# Epoch: 169 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.3710 | test_acc: 0.7375
# Epoch: 170 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.4748 | test_acc: 0.7271
# Epoch: 171 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.3345 | test_acc: 0.7583
# Epoch: 172 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.5361 | test_acc: 0.7271
# Epoch: 173 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.3835 | test_acc: 0.7583
# Epoch: 174 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.4043 | test_acc: 0.7583
# Epoch: 175 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4770 | test_acc: 0.7375
# Epoch: 176 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4536 | test_acc: 0.7375
# Epoch: 177 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4365 | test_acc: 0.7583
# Epoch: 178 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4832 | test_acc: 0.7375
# Epoch: 179 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.5422 | test_acc: 0.7375
# Epoch: 180 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4786 | test_acc: 0.7583
# Epoch: 181 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.5185 | test_acc: 0.7375
# Epoch: 182 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.5988 | test_acc: 0.7375
# Epoch: 183 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.4669 | test_acc: 0.7583
# Epoch: 184 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.4863 | test_acc: 0.7583
# Epoch: 185 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6902 | test_acc: 0.7271
# Epoch: 186 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.5454 | test_acc: 0.7583
# Epoch: 187 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.5096 | test_acc: 0.7583
# Epoch: 188 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6165 | test_acc: 0.7375
# Epoch: 189 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6195 | test_acc: 0.7375
# Epoch: 190 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.5917 | test_acc: 0.7479
# Epoch: 191 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.5576 | test_acc: 0.7583
# Epoch: 192 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6590 | test_acc: 0.7375
# Epoch: 193 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.6548 | test_acc: 0.7375
# Epoch: 194 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.5543 | test_acc: 0.7583
# Epoch: 195 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6701 | test_acc: 0.7375
# Epoch: 196 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6817 | test_acc: 0.7375
# Epoch: 197 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6239 | test_acc: 0.7583
# Epoch: 198 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6712 | test_acc: 0.7479
# Epoch: 199 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7225 | test_acc: 0.7375
# Epoch: 200 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6115 | test_acc: 0.7583
# Epoch: 201 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.6873 | test_acc: 0.7479
# Epoch: 202 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7242 | test_acc: 0.7375
# Epoch: 203 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7211 | test_acc: 0.7479
# Epoch: 204 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.6770 | test_acc: 0.7583
# Epoch: 205 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7225 | test_acc: 0.7479
# Epoch: 206 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7969 | test_acc: 0.7375
# Epoch: 207 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7592 | test_acc: 0.7479
# Epoch: 208 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7515 | test_acc: 0.7479
# Epoch: 209 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7878 | test_acc: 0.7375
# Epoch: 210 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7710 | test_acc: 0.7479
# Epoch: 211 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8109 | test_acc: 0.7375
# Epoch: 212 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7882 | test_acc: 0.7479
# Epoch: 213 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.7998 | test_acc: 0.7479
# Epoch: 214 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7910 | test_acc: 0.7583
# Epoch: 215 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8390 | test_acc: 0.7375
# Epoch: 216 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8574 | test_acc: 0.7375
# Epoch: 217 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.7773 | test_acc: 0.7583
# Epoch: 218 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8912 | test_acc: 0.7375
# Epoch: 219 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8906 | test_acc: 0.7375
# Epoch: 220 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8610 | test_acc: 0.7479
# Epoch: 221 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8894 | test_acc: 0.7479
# Epoch: 222 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8589 | test_acc: 0.7583
# Epoch: 223 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8809 | test_acc: 0.7479
# Epoch: 224 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8830 | test_acc: 0.7479
# Epoch: 225 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9502 | test_acc: 0.7375
# Epoch: 226 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.8279 | test_acc: 0.7583
# Epoch: 227 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9233 | test_acc: 0.7479
# Epoch: 228 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0177 | test_acc: 0.7375
# Epoch: 229 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9017 | test_acc: 0.7583
# Epoch: 230 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9064 | test_acc: 0.7583
# Epoch: 231 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0004 | test_acc: 0.7375
# Epoch: 232 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9840 | test_acc: 0.7375
# Epoch: 233 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9599 | test_acc: 0.7479
# Epoch: 234 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0080 | test_acc: 0.7375
# Epoch: 235 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0025 | test_acc: 0.7479
# Epoch: 236 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9777 | test_acc: 0.7479
# Epoch: 237 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9789 | test_acc: 0.7479
# Epoch: 238 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9876 | test_acc: 0.7479
# Epoch: 239 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 5.1007 | test_acc: 0.7375
# Epoch: 240 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0313 | test_acc: 0.7479
# Epoch: 241 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 4.9841 | test_acc: 0.7583
# Epoch: 242 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0063 | test_acc: 0.7583
# Epoch: 243 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0758 | test_acc: 0.7479
# Epoch: 244 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.1008 | test_acc: 0.7375
# Epoch: 245 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 5.0083 | test_acc: 0.7583
# Epoch: 246 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 5.0384 | test_acc: 0.7583
# Epoch: 247 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 5.0813 | test_acc: 0.7479
# Epoch: 248 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 5.1113 | test_acc: 0.7479
# Epoch: 249 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 5.0350 | test_acc: 0.7583
# Epoch: 250 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 4.9991 | test_acc: 0.7583
# Total training time: 467.964 seconds

# %%
model_0_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
def plot_loss_curves(results: Dict[str, List[float]]):

    loss = results['train_loss']
    test_loss = results['test_loss']

    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    epochs = range(len(results['train_loss']))

    plt.figure(figsize=(15, 7))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, test_loss, label='test_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, test_accuracy, label='test_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# ### Altering the Model with Data Aug

# %%
train_transform_trivial_augment = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.TrivialAugmentWide(num_magnitude_bins=31),
    transforms.ToTensor()
])

# Create testing transform (no data augmentation)
test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# %%
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.TrivialAugmentWide(num_magnitude_bins=31),
    transforms.ToTensor()
])

test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform_trivial_augment)
test_data_simple = datasets.ImageFolder(test_dir, transform=test_transform)

train_data_augmented, test_data_simple
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 204
#      Root location: /content/drive/MyDrive/Skin_Data_2/train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                 TrivialAugmentWide(num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#                 ToTensor()
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 84
#      Root location: /content/drive/MyDrive/Skin_Data_2/test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                 ToTensor()
#             ))

# %%
BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()

torch.manual_seed(42)
train_dataloader_augmented = DataLoader(train_data_augmented,
                                        batch_size=BATCH_SIZE,
                                        shuffle=True,
                                        num_workers=NUM_WORKERS)

test_dataloader_simple = DataLoader(test_data_simple,
                                    batch_size=BATCH_SIZE,
                                    shuffle=False,
                                    num_workers=NUM_WORKERS)

train_dataloader_augmented, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fc70ad4c580>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fc706b64070>)

# %%
torch.manual_seed(42)
model_1 = TinyVGG(
    input_shape=3,
    hidden_units=6,
    output_shape=len(train_data_augmented.classes)).to(device)
model_1
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1536, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCHS = 250

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_1.parameters(), lr=0.001)

from timeit import default_timer as timer
start_time = timer()

model_1_results = train(model=model_1,
                        train_dataloader=train_dataloader_augmented,
                        test_dataloader=test_dataloader_simple,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)

end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.6073 | train_acc: 0.7753 | test_loss: 0.8087 | test_acc: 0.5625
# Epoch: 2 | train_loss: 0.5108 | train_acc: 0.7976 | test_loss: 0.9166 | test_acc: 0.5625
# Epoch: 3 | train_loss: 0.4972 | train_acc: 0.8051 | test_loss: 0.8237 | test_acc: 0.5625
# Epoch: 4 | train_loss: 0.4958 | train_acc: 0.8051 | test_loss: 0.8011 | test_acc: 0.5625
# Epoch: 5 | train_loss: 0.5135 | train_acc: 0.7902 | test_loss: 0.8347 | test_acc: 0.5625
# Epoch: 6 | train_loss: 0.5028 | train_acc: 0.7976 | test_loss: 0.8390 | test_acc: 0.5625
# Epoch: 7 | train_loss: 0.5012 | train_acc: 0.7976 | test_loss: 0.8399 | test_acc: 0.5625
# Epoch: 8 | train_loss: 0.5100 | train_acc: 0.7902 | test_loss: 0.8171 | test_acc: 0.5625
# Epoch: 9 | train_loss: 0.5105 | train_acc: 0.7902 | test_loss: 0.8441 | test_acc: 0.5625
# Epoch: 10 | train_loss: 0.5101 | train_acc: 0.7902 | test_loss: 0.8312 | test_acc: 0.5625
# Epoch: 11 | train_loss: 0.5081 | train_acc: 0.7902 | test_loss: 0.8217 | test_acc: 0.5625
# Epoch: 12 | train_loss: 0.5264 | train_acc: 0.7753 | test_loss: 0.8677 | test_acc: 0.5625
# Epoch: 13 | train_loss: 0.4937 | train_acc: 0.7976 | test_loss: 0.8010 | test_acc: 0.5625
# Epoch: 14 | train_loss: 0.4721 | train_acc: 0.8125 | test_loss: 0.8831 | test_acc: 0.5625
# Epoch: 15 | train_loss: 0.5116 | train_acc: 0.7976 | test_loss: 0.8769 | test_acc: 0.5625
# Epoch: 16 | train_loss: 0.4932 | train_acc: 0.7976 | test_loss: 0.7827 | test_acc: 0.5625
# Epoch: 17 | train_loss: 0.4993 | train_acc: 0.7902 | test_loss: 0.9047 | test_acc: 0.5625
# Epoch: 18 | train_loss: 0.4838 | train_acc: 0.7976 | test_loss: 0.8620 | test_acc: 0.5625
# Epoch: 19 | train_loss: 0.4974 | train_acc: 0.7902 | test_loss: 0.7745 | test_acc: 0.5625
# Epoch: 20 | train_loss: 0.4729 | train_acc: 0.7976 | test_loss: 0.8538 | test_acc: 0.5625
# Epoch: 21 | train_loss: 0.4849 | train_acc: 0.8125 | test_loss: 0.7668 | test_acc: 0.5625
# Epoch: 22 | train_loss: 0.4736 | train_acc: 0.7976 | test_loss: 0.7514 | test_acc: 0.5625
# Epoch: 23 | train_loss: 0.5164 | train_acc: 0.7753 | test_loss: 0.8770 | test_acc: 0.5625
# Epoch: 24 | train_loss: 0.4974 | train_acc: 0.7902 | test_loss: 0.7108 | test_acc: 0.5625
# Epoch: 25 | train_loss: 0.4948 | train_acc: 0.7902 | test_loss: 0.7933 | test_acc: 0.5625
# Epoch: 26 | train_loss: 0.4691 | train_acc: 0.7738 | test_loss: 0.7451 | test_acc: 0.5625
# Epoch: 27 | train_loss: 0.5026 | train_acc: 0.7634 | test_loss: 0.7852 | test_acc: 0.5625
# Epoch: 28 | train_loss: 0.4810 | train_acc: 0.7932 | test_loss: 0.7805 | test_acc: 0.5625
# Epoch: 29 | train_loss: 0.4296 | train_acc: 0.8051 | test_loss: 0.8048 | test_acc: 0.5625
# Epoch: 30 | train_loss: 0.4590 | train_acc: 0.7902 | test_loss: 0.7614 | test_acc: 0.5625
# Epoch: 31 | train_loss: 0.4355 | train_acc: 0.7887 | test_loss: 0.7513 | test_acc: 0.5625
# Epoch: 32 | train_loss: 0.4475 | train_acc: 0.7976 | test_loss: 0.7289 | test_acc: 0.5729
# Epoch: 33 | train_loss: 0.4778 | train_acc: 0.7574 | test_loss: 0.7946 | test_acc: 0.5625
# Epoch: 34 | train_loss: 0.4152 | train_acc: 0.8095 | test_loss: 0.6570 | test_acc: 0.5938
# Epoch: 35 | train_loss: 0.4158 | train_acc: 0.8259 | test_loss: 0.8644 | test_acc: 0.5625
# Epoch: 36 | train_loss: 0.4241 | train_acc: 0.8125 | test_loss: 0.7538 | test_acc: 0.5833
# Epoch: 37 | train_loss: 0.4533 | train_acc: 0.7872 | test_loss: 0.7446 | test_acc: 0.5625
# Epoch: 38 | train_loss: 0.4878 | train_acc: 0.8065 | test_loss: 0.6583 | test_acc: 0.5729
# Epoch: 39 | train_loss: 0.4408 | train_acc: 0.7946 | test_loss: 0.7782 | test_acc: 0.5625
# Epoch: 40 | train_loss: 0.4255 | train_acc: 0.7917 | test_loss: 0.6578 | test_acc: 0.5938
# Epoch: 41 | train_loss: 0.4633 | train_acc: 0.7798 | test_loss: 0.6952 | test_acc: 0.5729
# Epoch: 42 | train_loss: 0.4017 | train_acc: 0.8333 | test_loss: 0.8732 | test_acc: 0.5938
# Epoch: 43 | train_loss: 0.4335 | train_acc: 0.7783 | test_loss: 0.7052 | test_acc: 0.5729
# Epoch: 44 | train_loss: 0.4655 | train_acc: 0.8036 | test_loss: 0.7444 | test_acc: 0.5625
# Epoch: 45 | train_loss: 0.4468 | train_acc: 0.7932 | test_loss: 0.7268 | test_acc: 0.5625
# Epoch: 46 | train_loss: 0.4199 | train_acc: 0.7902 | test_loss: 0.7383 | test_acc: 0.5625
# Epoch: 47 | train_loss: 0.4528 | train_acc: 0.7783 | test_loss: 0.6901 | test_acc: 0.5938
# Epoch: 48 | train_loss: 0.4322 | train_acc: 0.7842 | test_loss: 0.6673 | test_acc: 0.6042
# Epoch: 49 | train_loss: 0.3883 | train_acc: 0.8095 | test_loss: 0.7651 | test_acc: 0.5729
# Epoch: 50 | train_loss: 0.3791 | train_acc: 0.8408 | test_loss: 0.6566 | test_acc: 0.6458
# Epoch: 51 | train_loss: 0.3996 | train_acc: 0.7917 | test_loss: 0.7032 | test_acc: 0.6354
# Epoch: 52 | train_loss: 0.4111 | train_acc: 0.8125 | test_loss: 0.6700 | test_acc: 0.5833
# Epoch: 53 | train_loss: 0.4150 | train_acc: 0.7991 | test_loss: 0.7236 | test_acc: 0.5625
# Epoch: 54 | train_loss: 0.3885 | train_acc: 0.8170 | test_loss: 0.5608 | test_acc: 0.7083
# Epoch: 55 | train_loss: 0.3873 | train_acc: 0.8393 | test_loss: 0.7239 | test_acc: 0.6354
# Epoch: 56 | train_loss: 0.3861 | train_acc: 0.7857 | test_loss: 0.6088 | test_acc: 0.7188
# Epoch: 57 | train_loss: 0.3894 | train_acc: 0.8274 | test_loss: 0.7232 | test_acc: 0.5938
# Epoch: 58 | train_loss: 0.3975 | train_acc: 0.8229 | test_loss: 0.7917 | test_acc: 0.5625
# Epoch: 59 | train_loss: 0.3854 | train_acc: 0.8051 | test_loss: 0.7018 | test_acc: 0.5729
# Epoch: 60 | train_loss: 0.3685 | train_acc: 0.8125 | test_loss: 0.6719 | test_acc: 0.6667
# Epoch: 61 | train_loss: 0.3900 | train_acc: 0.8110 | test_loss: 0.6492 | test_acc: 0.6979
# Epoch: 62 | train_loss: 0.4168 | train_acc: 0.8110 | test_loss: 0.6442 | test_acc: 0.6146
# Epoch: 63 | train_loss: 0.4025 | train_acc: 0.8036 | test_loss: 0.6358 | test_acc: 0.6354
# Epoch: 64 | train_loss: 0.4005 | train_acc: 0.7753 | test_loss: 0.8756 | test_acc: 0.5833
# Epoch: 65 | train_loss: 0.3643 | train_acc: 0.8393 | test_loss: 0.5785 | test_acc: 0.7229
# Epoch: 66 | train_loss: 0.3734 | train_acc: 0.8333 | test_loss: 0.6884 | test_acc: 0.6354
# Epoch: 67 | train_loss: 0.3777 | train_acc: 0.8155 | test_loss: 0.7864 | test_acc: 0.5729
# Epoch: 68 | train_loss: 0.3922 | train_acc: 0.8021 | test_loss: 0.6836 | test_acc: 0.6500
# Epoch: 69 | train_loss: 0.3871 | train_acc: 0.7932 | test_loss: 0.6265 | test_acc: 0.7021
# Epoch: 70 | train_loss: 0.3709 | train_acc: 0.8408 | test_loss: 0.7201 | test_acc: 0.5833
# Epoch: 71 | train_loss: 0.3683 | train_acc: 0.8110 | test_loss: 0.6768 | test_acc: 0.5938
# Epoch: 72 | train_loss: 0.3464 | train_acc: 0.8661 | test_loss: 0.6877 | test_acc: 0.6458
# Epoch: 73 | train_loss: 0.3720 | train_acc: 0.8095 | test_loss: 0.6994 | test_acc: 0.6667
# Epoch: 74 | train_loss: 0.3984 | train_acc: 0.8199 | test_loss: 0.6680 | test_acc: 0.6354
# Epoch: 75 | train_loss: 0.4080 | train_acc: 0.8259 | test_loss: 0.6136 | test_acc: 0.6875
# Epoch: 76 | train_loss: 0.3637 | train_acc: 0.8274 | test_loss: 0.5994 | test_acc: 0.7438
# Epoch: 77 | train_loss: 0.3309 | train_acc: 0.8378 | test_loss: 0.8045 | test_acc: 0.6146
# Epoch: 78 | train_loss: 0.3651 | train_acc: 0.8229 | test_loss: 0.6105 | test_acc: 0.7438
# Epoch: 79 | train_loss: 0.3399 | train_acc: 0.8557 | test_loss: 0.6111 | test_acc: 0.7542
# Epoch: 80 | train_loss: 0.3498 | train_acc: 0.8601 | test_loss: 0.6515 | test_acc: 0.7438
# Epoch: 81 | train_loss: 0.4220 | train_acc: 0.8185 | test_loss: 0.7549 | test_acc: 0.5729
# Epoch: 82 | train_loss: 0.3905 | train_acc: 0.8274 | test_loss: 0.6965 | test_acc: 0.5833
# Epoch: 83 | train_loss: 0.3819 | train_acc: 0.8259 | test_loss: 0.6770 | test_acc: 0.6250
# Epoch: 84 | train_loss: 0.3454 | train_acc: 0.8393 | test_loss: 0.7476 | test_acc: 0.6458
# Epoch: 85 | train_loss: 0.3455 | train_acc: 0.8482 | test_loss: 0.6168 | test_acc: 0.6979
# Epoch: 86 | train_loss: 0.3745 | train_acc: 0.8408 | test_loss: 0.5934 | test_acc: 0.7500
# Epoch: 87 | train_loss: 0.3048 | train_acc: 0.8824 | test_loss: 0.6580 | test_acc: 0.7396
# Epoch: 88 | train_loss: 0.4158 | train_acc: 0.8125 | test_loss: 0.8327 | test_acc: 0.6146
# Epoch: 89 | train_loss: 0.3591 | train_acc: 0.8140 | test_loss: 0.6852 | test_acc: 0.6500
# Epoch: 90 | train_loss: 0.3863 | train_acc: 0.8318 | test_loss: 0.6059 | test_acc: 0.7438
# Epoch: 91 | train_loss: 0.3215 | train_acc: 0.8661 | test_loss: 0.7001 | test_acc: 0.6500
# Epoch: 92 | train_loss: 0.3786 | train_acc: 0.8185 | test_loss: 0.6474 | test_acc: 0.7396
# Epoch: 93 | train_loss: 0.3390 | train_acc: 0.8765 | test_loss: 0.6171 | test_acc: 0.7083
# Epoch: 94 | train_loss: 0.3735 | train_acc: 0.8452 | test_loss: 0.6986 | test_acc: 0.6979
# Epoch: 95 | train_loss: 0.2974 | train_acc: 0.8720 | test_loss: 0.5939 | test_acc: 0.7417
# Epoch: 96 | train_loss: 0.3347 | train_acc: 0.8676 | test_loss: 0.8098 | test_acc: 0.5938
# Epoch: 97 | train_loss: 0.3701 | train_acc: 0.8363 | test_loss: 0.6578 | test_acc: 0.6875
# Epoch: 98 | train_loss: 0.3363 | train_acc: 0.8497 | test_loss: 0.7400 | test_acc: 0.6875
# Epoch: 99 | train_loss: 0.3646 | train_acc: 0.8408 | test_loss: 0.7054 | test_acc: 0.6354
# Epoch: 100 | train_loss: 0.3599 | train_acc: 0.8557 | test_loss: 0.5757 | test_acc: 0.7812
# Epoch: 101 | train_loss: 0.3591 | train_acc: 0.8497 | test_loss: 0.7127 | test_acc: 0.6667
# Epoch: 102 | train_loss: 0.3348 | train_acc: 0.8318 | test_loss: 0.6357 | test_acc: 0.7438
# Epoch: 103 | train_loss: 0.3399 | train_acc: 0.8333 | test_loss: 0.7323 | test_acc: 0.6979
# Epoch: 104 | train_loss: 0.3752 | train_acc: 0.8333 | test_loss: 0.7056 | test_acc: 0.6250
# Epoch: 105 | train_loss: 0.3471 | train_acc: 0.8289 | test_loss: 0.6420 | test_acc: 0.6979
# Epoch: 106 | train_loss: 0.3329 | train_acc: 0.8542 | test_loss: 0.6509 | test_acc: 0.6875
# Epoch: 107 | train_loss: 0.3318 | train_acc: 0.8571 | test_loss: 0.5955 | test_acc: 0.7500
# Epoch: 108 | train_loss: 0.2977 | train_acc: 0.8869 | test_loss: 0.6876 | test_acc: 0.7292
# Epoch: 109 | train_loss: 0.3978 | train_acc: 0.8259 | test_loss: 0.6477 | test_acc: 0.7500
# Epoch: 110 | train_loss: 0.2797 | train_acc: 0.8676 | test_loss: 0.6535 | test_acc: 0.7188
# Epoch: 111 | train_loss: 0.3427 | train_acc: 0.8482 | test_loss: 0.6307 | test_acc: 0.7229
# Epoch: 112 | train_loss: 0.3669 | train_acc: 0.8274 | test_loss: 0.6923 | test_acc: 0.6979
# Epoch: 113 | train_loss: 0.2786 | train_acc: 0.8750 | test_loss: 0.5564 | test_acc: 0.8021
# Epoch: 114 | train_loss: 0.3133 | train_acc: 0.8929 | test_loss: 0.5428 | test_acc: 0.8167
# Epoch: 115 | train_loss: 0.3342 | train_acc: 0.8720 | test_loss: 0.6553 | test_acc: 0.7438
# Epoch: 116 | train_loss: 0.3193 | train_acc: 0.8601 | test_loss: 0.6378 | test_acc: 0.7396
# Epoch: 117 | train_loss: 0.4295 | train_acc: 0.8289 | test_loss: 0.6191 | test_acc: 0.7396
# Epoch: 118 | train_loss: 0.3869 | train_acc: 0.8185 | test_loss: 0.8089 | test_acc: 0.6292
# Epoch: 119 | train_loss: 0.4200 | train_acc: 0.8110 | test_loss: 0.7606 | test_acc: 0.6292
# Epoch: 120 | train_loss: 0.3758 | train_acc: 0.8542 | test_loss: 0.6510 | test_acc: 0.6813
# Epoch: 121 | train_loss: 0.2789 | train_acc: 0.8705 | test_loss: 0.7943 | test_acc: 0.6354
# Epoch: 122 | train_loss: 0.3892 | train_acc: 0.8333 | test_loss: 0.6084 | test_acc: 0.7396
# Epoch: 123 | train_loss: 0.3337 | train_acc: 0.8571 | test_loss: 0.6398 | test_acc: 0.7188
# Epoch: 124 | train_loss: 0.2818 | train_acc: 0.8780 | test_loss: 0.6078 | test_acc: 0.7604
# Epoch: 125 | train_loss: 0.2948 | train_acc: 0.8780 | test_loss: 0.6723 | test_acc: 0.7396
# Epoch: 126 | train_loss: 0.2792 | train_acc: 0.8824 | test_loss: 0.7776 | test_acc: 0.7083
# Epoch: 127 | train_loss: 0.2753 | train_acc: 0.8765 | test_loss: 0.5664 | test_acc: 0.7958
# Epoch: 128 | train_loss: 0.3459 | train_acc: 0.8616 | test_loss: 0.6032 | test_acc: 0.7646
# Epoch: 129 | train_loss: 0.2418 | train_acc: 0.9062 | test_loss: 0.6895 | test_acc: 0.7229
# Epoch: 130 | train_loss: 0.2684 | train_acc: 0.8765 | test_loss: 0.8990 | test_acc: 0.6500
# Epoch: 131 | train_loss: 0.3268 | train_acc: 0.8438 | test_loss: 0.6924 | test_acc: 0.7438
# Epoch: 132 | train_loss: 0.3243 | train_acc: 0.8676 | test_loss: 0.6719 | test_acc: 0.6875
# Epoch: 133 | train_loss: 0.2967 | train_acc: 0.8661 | test_loss: 0.7124 | test_acc: 0.6708
# Epoch: 134 | train_loss: 0.3584 | train_acc: 0.8438 | test_loss: 0.7224 | test_acc: 0.6813
# Epoch: 135 | train_loss: 0.3431 | train_acc: 0.8557 | test_loss: 0.6545 | test_acc: 0.6813
# Epoch: 136 | train_loss: 0.2798 | train_acc: 0.8735 | test_loss: 0.7264 | test_acc: 0.6813
# Epoch: 137 | train_loss: 0.2620 | train_acc: 0.9018 | test_loss: 0.5837 | test_acc: 0.7750
# Epoch: 138 | train_loss: 0.2667 | train_acc: 0.8884 | test_loss: 0.5800 | test_acc: 0.7958
# Epoch: 139 | train_loss: 0.2951 | train_acc: 0.8676 | test_loss: 0.5719 | test_acc: 0.8063
# Epoch: 140 | train_loss: 0.2719 | train_acc: 0.9003 | test_loss: 0.7621 | test_acc: 0.7229
# Epoch: 141 | train_loss: 0.3417 | train_acc: 0.8333 | test_loss: 0.7375 | test_acc: 0.6917
# Epoch: 142 | train_loss: 0.2961 | train_acc: 0.9018 | test_loss: 0.6183 | test_acc: 0.7646
# Epoch: 143 | train_loss: 0.2993 | train_acc: 0.8646 | test_loss: 0.6812 | test_acc: 0.7333
# Epoch: 144 | train_loss: 0.4216 | train_acc: 0.8318 | test_loss: 0.6586 | test_acc: 0.7438
# Epoch: 145 | train_loss: 0.2876 | train_acc: 0.8839 | test_loss: 0.8876 | test_acc: 0.6396
# Epoch: 146 | train_loss: 0.3122 | train_acc: 0.8869 | test_loss: 0.5513 | test_acc: 0.7583
# Epoch: 147 | train_loss: 0.2974 | train_acc: 0.8497 | test_loss: 0.6774 | test_acc: 0.7292
# Epoch: 148 | train_loss: 0.2949 | train_acc: 0.8676 | test_loss: 0.6056 | test_acc: 0.7854
# Epoch: 149 | train_loss: 0.2851 | train_acc: 0.8988 | test_loss: 0.7241 | test_acc: 0.7229
# Epoch: 150 | train_loss: 0.2766 | train_acc: 0.8705 | test_loss: 0.6097 | test_acc: 0.7854
# Epoch: 151 | train_loss: 0.3086 | train_acc: 0.8958 | test_loss: 0.7186 | test_acc: 0.7229
# Epoch: 152 | train_loss: 0.3042 | train_acc: 0.8690 | test_loss: 0.7899 | test_acc: 0.6500
# Epoch: 153 | train_loss: 0.2672 | train_acc: 0.8765 | test_loss: 0.5493 | test_acc: 0.7958
# Epoch: 154 | train_loss: 0.3062 | train_acc: 0.8765 | test_loss: 0.7259 | test_acc: 0.7292
# Epoch: 155 | train_loss: 0.2496 | train_acc: 0.9033 | test_loss: 0.5883 | test_acc: 0.8125
# Epoch: 156 | train_loss: 0.2870 | train_acc: 0.8899 | test_loss: 0.6641 | test_acc: 0.7708
# Epoch: 157 | train_loss: 0.2457 | train_acc: 0.8943 | test_loss: 0.6578 | test_acc: 0.7438
# Epoch: 158 | train_loss: 0.2409 | train_acc: 0.9241 | test_loss: 0.5858 | test_acc: 0.8167
# Epoch: 159 | train_loss: 0.2437 | train_acc: 0.8899 | test_loss: 0.7780 | test_acc: 0.7438
# Epoch: 160 | train_loss: 0.3745 | train_acc: 0.8408 | test_loss: 0.7738 | test_acc: 0.6562
# Epoch: 161 | train_loss: 0.3384 | train_acc: 0.8408 | test_loss: 0.4865 | test_acc: 0.7729
# Epoch: 162 | train_loss: 0.3521 | train_acc: 0.8304 | test_loss: 0.7569 | test_acc: 0.6604
# Epoch: 163 | train_loss: 0.3100 | train_acc: 0.8586 | test_loss: 0.8494 | test_acc: 0.6604
# Epoch: 164 | train_loss: 0.3894 | train_acc: 0.8690 | test_loss: 0.6177 | test_acc: 0.7438
# Epoch: 165 | train_loss: 0.2678 | train_acc: 0.8899 | test_loss: 0.6247 | test_acc: 0.7333
# Epoch: 166 | train_loss: 0.2579 | train_acc: 0.9018 | test_loss: 0.5697 | test_acc: 0.7750
# Epoch: 167 | train_loss: 0.2252 | train_acc: 0.9420 | test_loss: 0.6019 | test_acc: 0.7958
# Epoch: 168 | train_loss: 0.3050 | train_acc: 0.8958 | test_loss: 0.8113 | test_acc: 0.7333
# Epoch: 169 | train_loss: 0.2251 | train_acc: 0.9122 | test_loss: 0.5959 | test_acc: 0.7854
# Epoch: 170 | train_loss: 0.3159 | train_acc: 0.8810 | test_loss: 0.6016 | test_acc: 0.7958
# Epoch: 171 | train_loss: 0.2634 | train_acc: 0.9048 | test_loss: 0.7322 | test_acc: 0.7083
# Epoch: 172 | train_loss: 0.3025 | train_acc: 0.9048 | test_loss: 0.5506 | test_acc: 0.8063
# Epoch: 173 | train_loss: 0.2460 | train_acc: 0.8914 | test_loss: 0.6538 | test_acc: 0.7854
# Epoch: 174 | train_loss: 0.2793 | train_acc: 0.8735 | test_loss: 0.6911 | test_acc: 0.7854
# Epoch: 175 | train_loss: 0.2448 | train_acc: 0.8899 | test_loss: 0.6398 | test_acc: 0.7958
# Epoch: 176 | train_loss: 0.2483 | train_acc: 0.8899 | test_loss: 0.7005 | test_acc: 0.7333
# Epoch: 177 | train_loss: 0.2480 | train_acc: 0.8943 | test_loss: 0.6464 | test_acc: 0.7646
# Epoch: 178 | train_loss: 0.2057 | train_acc: 0.9211 | test_loss: 0.7165 | test_acc: 0.7542
# Epoch: 179 | train_loss: 0.2373 | train_acc: 0.9152 | test_loss: 0.6051 | test_acc: 0.7958
# Epoch: 180 | train_loss: 0.2913 | train_acc: 0.8973 | test_loss: 0.7189 | test_acc: 0.7333
# Epoch: 181 | train_loss: 0.2247 | train_acc: 0.8943 | test_loss: 0.8466 | test_acc: 0.6708
# Epoch: 182 | train_loss: 0.2831 | train_acc: 0.8869 | test_loss: 0.6450 | test_acc: 0.7646
# Epoch: 183 | train_loss: 0.2319 | train_acc: 0.8988 | test_loss: 0.7299 | test_acc: 0.7438
# Epoch: 184 | train_loss: 0.2418 | train_acc: 0.8810 | test_loss: 0.7443 | test_acc: 0.7333
# Epoch: 185 | train_loss: 0.2207 | train_acc: 0.8958 | test_loss: 0.6808 | test_acc: 0.7646
# Epoch: 186 | train_loss: 0.2782 | train_acc: 0.8676 | test_loss: 0.6030 | test_acc: 0.7583
# Epoch: 187 | train_loss: 0.3013 | train_acc: 0.8854 | test_loss: 0.7041 | test_acc: 0.7438
# Epoch: 188 | train_loss: 0.2266 | train_acc: 0.9137 | test_loss: 0.5764 | test_acc: 0.7896
# Epoch: 189 | train_loss: 0.2641 | train_acc: 0.9048 | test_loss: 0.7003 | test_acc: 0.7646
# Epoch: 190 | train_loss: 0.2651 | train_acc: 0.8839 | test_loss: 0.6643 | test_acc: 0.7750
# Epoch: 191 | train_loss: 0.2136 | train_acc: 0.9152 | test_loss: 0.7433 | test_acc: 0.7438
# Epoch: 192 | train_loss: 0.3289 | train_acc: 0.8839 | test_loss: 0.6783 | test_acc: 0.7438
# Epoch: 193 | train_loss: 0.2447 | train_acc: 0.9286 | test_loss: 0.6267 | test_acc: 0.7542
# Epoch: 194 | train_loss: 0.2384 | train_acc: 0.9077 | test_loss: 0.7557 | test_acc: 0.7542
# Epoch: 195 | train_loss: 0.2884 | train_acc: 0.8869 | test_loss: 0.7979 | test_acc: 0.7229
# Epoch: 196 | train_loss: 0.3292 | train_acc: 0.8586 | test_loss: 0.6507 | test_acc: 0.7583
# Epoch: 197 | train_loss: 0.2147 | train_acc: 0.9167 | test_loss: 0.7832 | test_acc: 0.6917
# Epoch: 198 | train_loss: 0.2514 | train_acc: 0.8854 | test_loss: 0.6988 | test_acc: 0.7438
# Epoch: 199 | train_loss: 0.3268 | train_acc: 0.8705 | test_loss: 0.7221 | test_acc: 0.7438
# Epoch: 200 | train_loss: 0.2273 | train_acc: 0.9256 | test_loss: 0.7958 | test_acc: 0.7229
# Epoch: 201 | train_loss: 0.1919 | train_acc: 0.9152 | test_loss: 0.6589 | test_acc: 0.7750
# Epoch: 202 | train_loss: 0.2453 | train_acc: 0.9107 | test_loss: 0.7311 | test_acc: 0.7646
# Epoch: 203 | train_loss: 0.2209 | train_acc: 0.9211 | test_loss: 0.7735 | test_acc: 0.7646
# Epoch: 204 | train_loss: 0.2836 | train_acc: 0.8854 | test_loss: 0.6544 | test_acc: 0.8167
# Epoch: 205 | train_loss: 0.2636 | train_acc: 0.8884 | test_loss: 0.8355 | test_acc: 0.7125
# Epoch: 206 | train_loss: 0.2430 | train_acc: 0.9167 | test_loss: 0.7264 | test_acc: 0.7542
# Epoch: 207 | train_loss: 0.2402 | train_acc: 0.8914 | test_loss: 0.7097 | test_acc: 0.7646
# Epoch: 208 | train_loss: 0.2202 | train_acc: 0.9077 | test_loss: 0.6775 | test_acc: 0.7646
# Epoch: 209 | train_loss: 0.2733 | train_acc: 0.8795 | test_loss: 0.7407 | test_acc: 0.7542
# Epoch: 210 | train_loss: 0.2721 | train_acc: 0.8929 | test_loss: 0.7554 | test_acc: 0.7333
# Epoch: 211 | train_loss: 0.2211 | train_acc: 0.9256 | test_loss: 0.6627 | test_acc: 0.7542
# Epoch: 212 | train_loss: 0.2030 | train_acc: 0.9122 | test_loss: 0.6698 | test_acc: 0.7542
# Epoch: 213 | train_loss: 0.2834 | train_acc: 0.8958 | test_loss: 0.7784 | test_acc: 0.7292
# Epoch: 214 | train_loss: 0.2302 | train_acc: 0.9122 | test_loss: 0.6006 | test_acc: 0.7646
# Epoch: 215 | train_loss: 0.2413 | train_acc: 0.8943 | test_loss: 0.8971 | test_acc: 0.6917
# Epoch: 216 | train_loss: 0.2637 | train_acc: 0.8869 | test_loss: 0.7246 | test_acc: 0.7542
# Epoch: 217 | train_loss: 0.2536 | train_acc: 0.9048 | test_loss: 0.6335 | test_acc: 0.7750
# Epoch: 218 | train_loss: 0.2610 | train_acc: 0.9048 | test_loss: 0.7468 | test_acc: 0.7125
# Epoch: 219 | train_loss: 0.2591 | train_acc: 0.8914 | test_loss: 0.6038 | test_acc: 0.8063
# Epoch: 220 | train_loss: 0.2497 | train_acc: 0.8958 | test_loss: 0.7751 | test_acc: 0.7333
# Epoch: 221 | train_loss: 0.2103 | train_acc: 0.9226 | test_loss: 0.7663 | test_acc: 0.6917
# Epoch: 222 | train_loss: 0.2430 | train_acc: 0.9167 | test_loss: 0.7164 | test_acc: 0.7438
# Epoch: 223 | train_loss: 0.1953 | train_acc: 0.9256 | test_loss: 0.7976 | test_acc: 0.7438
# Epoch: 224 | train_loss: 0.2737 | train_acc: 0.9122 | test_loss: 0.7148 | test_acc: 0.7646
# Epoch: 225 | train_loss: 0.2142 | train_acc: 0.9211 | test_loss: 0.7769 | test_acc: 0.7542
# Epoch: 226 | train_loss: 0.2419 | train_acc: 0.8943 | test_loss: 0.7033 | test_acc: 0.7750
# Epoch: 227 | train_loss: 0.2079 | train_acc: 0.9301 | test_loss: 0.7013 | test_acc: 0.7854
# Epoch: 228 | train_loss: 0.2884 | train_acc: 0.8958 | test_loss: 0.6877 | test_acc: 0.7854
# Epoch: 229 | train_loss: 0.2192 | train_acc: 0.9301 | test_loss: 0.7642 | test_acc: 0.7542
# Epoch: 230 | train_loss: 0.2425 | train_acc: 0.9077 | test_loss: 0.7880 | test_acc: 0.7438
# Epoch: 231 | train_loss: 0.2337 | train_acc: 0.9211 | test_loss: 0.5788 | test_acc: 0.8208
# Epoch: 232 | train_loss: 0.2467 | train_acc: 0.9033 | test_loss: 0.8775 | test_acc: 0.7229
# Epoch: 233 | train_loss: 0.2574 | train_acc: 0.9301 | test_loss: 0.6120 | test_acc: 0.7792
# Epoch: 234 | train_loss: 0.2101 | train_acc: 0.9211 | test_loss: 0.7691 | test_acc: 0.7333
# Epoch: 235 | train_loss: 0.2213 | train_acc: 0.9241 | test_loss: 0.7490 | test_acc: 0.7750
# Epoch: 236 | train_loss: 0.2274 | train_acc: 0.8914 | test_loss: 0.7078 | test_acc: 0.7854
# Epoch: 237 | train_loss: 0.2472 | train_acc: 0.8914 | test_loss: 0.7150 | test_acc: 0.7854
# Epoch: 238 | train_loss: 0.2093 | train_acc: 0.9256 | test_loss: 0.5719 | test_acc: 0.8375
# Epoch: 239 | train_loss: 0.2349 | train_acc: 0.9122 | test_loss: 0.8074 | test_acc: 0.7333
# Epoch: 240 | train_loss: 0.2409 | train_acc: 0.9196 | test_loss: 0.7411 | test_acc: 0.7646
# Epoch: 241 | train_loss: 0.2293 | train_acc: 0.8914 | test_loss: 0.8198 | test_acc: 0.7229
# Epoch: 242 | train_loss: 0.1752 | train_acc: 0.9390 | test_loss: 0.6833 | test_acc: 0.7854
# Epoch: 243 | train_loss: 0.2317 | train_acc: 0.9301 | test_loss: 0.7863 | test_acc: 0.7333
# Epoch: 244 | train_loss: 0.2251 | train_acc: 0.9226 | test_loss: 0.6820 | test_acc: 0.7750
# Epoch: 245 | train_loss: 0.2294 | train_acc: 0.9182 | test_loss: 0.8498 | test_acc: 0.7229
# Epoch: 246 | train_loss: 0.2323 | train_acc: 0.9003 | test_loss: 0.6964 | test_acc: 0.7854
# Epoch: 247 | train_loss: 0.2287 | train_acc: 0.9003 | test_loss: 0.7006 | test_acc: 0.7854
# Epoch: 248 | train_loss: 0.2834 | train_acc: 0.8616 | test_loss: 0.7667 | test_acc: 0.7438
# Epoch: 249 | train_loss: 0.2027 | train_acc: 0.9315 | test_loss: 0.6353 | test_acc: 0.7750
# Epoch: 250 | train_loss: 0.2752 | train_acc: 0.9167 | test_loss: 0.7719 | test_acc: 0.7021
# Total training time: 486.224 seconds

# %%
plot_loss_curves(model_1_results)

# %%
model_0_df = pd.DataFrame(model_0_results)
model_1_df = pd.DataFrame(model_1_results)
model_0_df
# Out:
#      train_loss  train_acc  test_loss  test_acc
# 0      0.631494   0.700893   0.711668  0.562500
# 1      0.513283   0.797619   0.928937  0.562500
# 2      0.523693   0.797619   0.941571  0.562500
# 3      0.487799   0.812500   0.818479  0.562500
# 4      0.511902   0.790179   0.824090  0.562500
# ..          ...        ...        ...       ...
# 245    0.000143   1.000000   5.038377  0.758333
# 246    0.000137   1.000000   5.081313  0.747917
# 247    0.000141   1.000000   5.111320  0.747917
# 248    0.000167   1.000000   5.034954  0.758333
# 249    0.000141   1.000000   4.999095  0.758333
#
# [250 rows x 4 columns]

# %%
plt.figure(figsize=(15, 10))

epochs = range(len(model_0_df))

plt.subplot(2, 2, 1)
plt.plot(epochs, model_0_df["train_loss"], label="Model 0")
plt.plot(epochs, model_1_df["train_loss"], label="Model 1")
plt.title("Train Loss")
plt.xlabel("Epochs")
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, model_0_df["test_loss"], label="Model 0")
plt.plot(epochs, model_1_df["test_loss"], label="Model 1")
plt.title("Test Loss")
plt.xlabel("Epochs")
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, model_0_df["train_acc"], label="Model 0")
plt.plot(epochs, model_1_df["train_acc"], label="Model 1")
plt.title("Train Accuracy")
plt.xlabel("Epochs")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, model_0_df["test_acc"], label="Model 0")
plt.plot(epochs, model_1_df["test_acc"], label="Model 1")
plt.title("Test Accuracy")
plt.xlabel("Epochs")
plt.legend();

# %%
custom_image_path = data_path / "skincanceruk.jpeg"

if not custom_image_path.is_file():
    with open(custom_image_path, "wb") as f:
        # When downloading from GitHub, need to use the "raw" file link
        request = requests.get("https://assets.nhs.uk/nhsuk-cms/images/C0167371.max-600x600.jpg")
        print(f"Downloading {custom_image_path}...")
        f.write(request.content)
else:
    print(f"{custom_image_path} already exists, skipping download.")
# Out:
# /content/drive/MyDrive/skincanceruk.jpeg already exists, skipping download.

# %%
import torchvision


custom_image_uint8 = torchvision.io.read_image(str(custom_image_path))
custom_image = torchvision.io.read_image(str(custom_image_path)).type(torch.float32)

custom_image = custom_image / 255.

# %%
custom_image_transform = transforms.Compose([
    transforms.Resize((64, 64)),
])

custom_image_transformed = custom_image_transform(custom_image)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
model_1.eval()
with torch.inference_mode():
    custom_image_transformed_with_batch_size = custom_image_transformed.unsqueeze(dim=0)
    custom_image_pred = model_1(custom_image_transformed.unsqueeze(dim=0).to(device))

# %%
print(f"Prediction logits: {custom_image_pred}")

custom_image_pred_probs = torch.softmax(custom_image_pred, dim=1)
print(f"Prediction probabilities: {custom_image_pred_probs}")

custom_image_pred_label = torch.argmax(custom_image_pred_probs, dim=1)
print(f"Prediction label: {custom_image_pred_label}")
# Out:
# Prediction logits: tensor([[ 2.2931, -2.3848]], device='cuda:0')
# Prediction probabilities: tensor([[0.9908, 0.0092]], device='cuda:0')
# Prediction label: tensor([0], device='cuda:0')

# %%
custom_image_pred_class = class_names[custom_image_pred_label.cpu()] # put pred label to CPU, otherwise will error
custom_image_pred_class
# Out:
# 'Cancer'

# %%
def pred_and_plot_image(model: torch.nn.Module,
                        image_path: str,
                        class_names: List[str] = None,
                        transform=None,
                        device: torch.device = device):
    """Makes a prediction on a target image and plots the image with its prediction."""

    # 1. Load in image and convert the tensor values to float32
    target_image = torchvision.io.read_image(str(image_path)).type(torch.float32)

    # 2. Divide the image pixel values by 255 to get them between [0, 1]
    target_image = target_image / 255.

    # 3. Transform if necessary
    if transform:
        target_image = transform(target_image)

    # 4. Make sure the model is on the target device
    model.to(device)

    # 5. Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
        # Add an extra dimension to the image
        target_image = target_image.unsqueeze(dim=0)

        # Make a prediction on image with an extra dimension and send it to the target device
        target_image_pred = model(target_image.to(device))

    # 6. Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # 7. Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    # 8. Plot the image alongside the prediction and prediction probability
    plt.imshow(target_image.squeeze().permute(1, 2, 0)) # make sure it's the right size for matplotlib
    if class_names:
        title = f"Pred: {class_names[target_image_pred_label.cpu()]} | Prob: {target_image_pred_probs.max().cpu():.3f}"
    else:
        title = f"Pred: {target_image_pred_label} | Prob: {target_image_pred_probs.max().cpu():.3f}"
    plt.title(title)
    plt.axis(False);

# %%
pred_and_plot_image(model=model_1,
                    image_path=custom_image_path,
                    class_names=class_names,
                    transform=custom_image_transform,
                    device=device)
